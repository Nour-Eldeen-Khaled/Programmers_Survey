# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns

# %%
# read our excel 
df = pd.read_excel(r'D:\End-To-End_Project_Survey\Survey_Project_Before_Cleaning.xlsx')
df.head()
# Out:
#                   Unique ID      Email Date Taken (America/New_York)  \
# 0  62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1  62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2  62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3  62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4  62a33c91f3072dd892621e03  anonymous                     6/10/2022
#
#   Time Taken (America/New_York)  Browser  OS  City  Country  Referrer  \
# 0                          8:38      NaN NaN   NaN      NaN       NaN
# 1                          8:40      NaN NaN   NaN      NaN       NaN
# 2                          8:42      NaN NaN   NaN      NaN       NaN
# 3                          8:43      NaN NaN   NaN      NaN       NaN
# 4                          8:44      NaN NaN   NaN      NaN       NaN
#
#   Time Spent Q1 - Which Title Best Fits your Current Role?  \
# 0    0:00:44                                  Data Analyst
# ...

# %%
# Set the max_columns option to None
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#                   Unique ID      Email Date Taken (America/New_York)  \
# 0  62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1  62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2  62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3  62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4  62a33c91f3072dd892621e03  anonymous                     6/10/2022
#
#   Time Taken (America/New_York)  Browser  OS  City  Country  Referrer  \
# 0                          8:38      NaN NaN   NaN      NaN       NaN
# 1                          8:40      NaN NaN   NaN      NaN       NaN
# 2                          8:42      NaN NaN   NaN      NaN       NaN
# 3                          8:43      NaN NaN   NaN      NaN       NaN
# 4                          8:44      NaN NaN   NaN      NaN       NaN
#
#   Time Spent Q1 - Which Title Best Fits your Current Role?  \
# 0    0:00:44                                  Data Analyst
# ...

# %%
# see the info about our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 28 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Unique ID                                                                                     630 non-null    object
#  1   Email                                                                                         630 non-null    object
#  2   Date Taken (America/New_York)                                                                 630 non-null    object
#  3   Time Taken (America/New_York)                                                                 630 non-null    object
#  4   Browser                                                                                       0 non-null      float64
# ...

# %%
# see how many rows and columns our data is
df.shape
# Out:
# (630, 28)

# %%
# drop unusable columns
df.drop(columns=["Email","Browser","OS","City","Date Taken (America/New_York)","Time Taken (America/New_York)",
                "Country","Referrer","Time Spent"],inplace = True)
df.head()
# Out:
#                   Unique ID Q1 - Which Title Best Fits your Current Role?  \
# 0  62a33b3db4da29969c62df3d                                  Data Analyst
# 1  62a33ba1bae91e4b8b82e35c                                  Data Analyst
# 2  62a33c2cbc6861bf3176bec1                                 Data Engineer
# 3  62a33c8624a26260273822f9  Other (Please Specify):Analytics Consultant
# 4  62a33c91f3072dd892621e03                                  Data Analyst
#
#   Q2 - Did you switch careers into Data? Q3 - Current Yearly Salary (in USD)  \
# 0                                    Yes                           106k-125k
# 1                                     No                             41k-65k
# 2                                     No                               0-40k
# 3                                    Yes                           150k-225k
# 4                                    Yes                             41k-65k
#
# ...

# %%
# Rename columns to be more reasonable 
df.rename(columns={'Q1 - Which Title Best Fits your Current Role?':'Job Title',
                   'Q2 - Did you switch careers into Data?':'Career Switch',
                   'Q3 - Current Yearly Salary (in USD)':'Yearly Salary(in USD)',
                   'Q4 - What Industry do you work in?':'Work Industry',
                   'Q6 - How Happy are you in your Current Position with the following? (Salary)':'Happiness(Salary)',
                   'Q6 - How Happy are you in your Current Position with the following? (Work/Life Balance)':'Happiness(Work/Life Balance)',
                   'Q6 - How Happy are you in your Current Position with the following? (Coworkers)':'Happiness(Coworkers)',
                   'Q6 - How Happy are you in your Current Position with the following? (Management)':'Happiness(Management)',
                   'Q6 - How Happy are you in your Current Position with the following? (Upward Mobility)':'Happiness(Upward Mobility)',
                   'Q6 - How Happy are you in your Current Position with the following? (Learning New Things)':'Happiness(Learning New Things)',
                   'Q7 - How difficult was it for you to break into Data?':'Difficulty of Breaking into Data',
                   'Q8 - If you were to look for a new job today, what would be the most important thing to you?':'what do you look for in a new job',
                   'Q9 - Male/Female?':'Male/Female',
                   'Q10 - Current Age':'Age',
                   'Q11 - Which Country do you live in?':'Country',
                   'Q12 - Highest Level of Education':'Education Level',
                   'Q13 - Ethnicity':'Ethnicity',
                   'Q5 - Favorite Programming Language':'Favorite Programming Language'},inplace=True)
df.head()
# Out:
#                   Unique ID                                     Job Title  \
# 0  62a33b3db4da29969c62df3d                                  Data Analyst
# 1  62a33ba1bae91e4b8b82e35c                                  Data Analyst
# 2  62a33c2cbc6861bf3176bec1                                 Data Engineer
# 3  62a33c8624a26260273822f9  Other (Please Specify):Analytics Consultant
# 4  62a33c91f3072dd892621e03                                  Data Analyst
#
#   Career Switch Yearly Salary(in USD)                        Work Industry  \
# 0           Yes             106k-125k                           Healthcare
# 1            No               41k-65k                              Finance
# 2            No                 0-40k  Other (Please Specify):Clean Energy
# 3           Yes             150k-225k                              Finance
# 4           Yes               41k-65k                           Healthcare
#
#   Favorite Programming Language  Happiness(Salary)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unique ID                          630 non-null    object
#  1   Job Title                          630 non-null    object
#  2   Career Switch                      630 non-null    object
#  3   Yearly Salary(in USD)              630 non-null    object
#  4   Work Industry                      630 non-null    object
#  5   Favorite Programming Language      630 non-null    object
#  6   Happiness(Salary)                  623 non-null    float64
#  7   Happiness(Work/Life Balance)       620 non-null    float64
#  8   Happiness(Coworkers)               619 non-null    float64
#  9   Happiness(Management)              618 non-null    float64
#  10  Happiness(Upward Mobility)         617 non-null    float64
# ...

# %%
df.shape
# Out:
# (630, 19)

# %%
# see the nulls in our data 
df.isnull().sum()
# Out:
# Unique ID                             0
# Job Title                             0
# Career Switch                         0
# Yearly Salary(in USD)                 0
# Work Industry                         0
# Favorite Programming Language         0
# Happiness(Salary)                     7
# Happiness(Work/Life Balance)         10
# Happiness(Coworkers)                 11
# Happiness(Management)                12
# Happiness(Upward Mobility)           13
# Happiness(Learning New Things)        5
# Difficulty of Breaking into Data      0
# what do you look for in a new job     0
# Male/Female                           0
# Age                                   0
# Country                               0
# Education Level                      52
# Ethnicity                             0
# dtype: int64

# %%
# Lets see the precentage of each missing data

df.isnull().sum() / df.shape[0] * 100
# Out:
# Unique ID                            0.000000
# Job Title                            0.000000
# Career Switch                        0.000000
# Yearly Salary(in USD)                0.000000
# Work Industry                        0.000000
# Favorite Programming Language        0.000000
# Happiness(Salary)                    1.111111
# Happiness(Work/Life Balance)         1.587302
# Happiness(Coworkers)                 1.746032
# Happiness(Management)                1.904762
# Happiness(Upward Mobility)           2.063492
# Happiness(Learning New Things)       0.793651
# Difficulty of Breaking into Data     0.000000
# what do you look for in a new job    0.000000
# Male/Female                          0.000000
# Age                                  0.000000
# Country                              0.000000
# Education Level                      8.253968
# Ethnicity                            0.000000
# dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States                                           261
# India                                                    73
# United Kingdom                                           40
# Canada                                                   32
# Other (Please Specify):Nigeria                           18
# Other (Please Specify):Germany                           14
# Other (Please Specify):Nigeria                           10
# Other (Please Specify):Spain                              9
# Other (Please Specify):Australia                          8
# Other (Please Specify):Poland                             6
# Other (Please Specify):Egypt                              6
# Other (Please Specify):Costa Rica                         6
# Other (Please Specify):Kenya                              6
# Other (Please Specify):Mexico                             6
# Other (Please Specify):Netherlands                        5
# Other (Please Specify):Portugal                           5
# ...

# %%
df['Work Industry'].value_counts()[lambda x: x > 1]
# Out:
# Tech                                      149
# Finance                                    94
# Healthcare                                 83
# Education                                  38
# Telecommunication                          22
# Construction                               14
# Other (Please Specify):Retail              14
# Real Estate                                13
# Other (Please Specify):Consulting           8
# Other (Please Specify):Automotive           7
# Other (Please Specify):Manufacturing        7
# Agriculture                                 7
# Other (Please Specify)                      5
# Other (Please Specify):Logistics            4
# Other (Please Specify):Marketing            4
# Other (Please Specify):Insurance            3
# Other (Please Specify):Distribution         3
# Other (Please Specify):Energy               3
# Other (Please Specify):E-commerce           2
# Other (Please Specify):Marketing            2
# ...

# %%
len(df['Work Industry'].value_counts()[lambda x: x == 1])
# Out:
# 113

# %%
#df['Favorite Programming Language'].value_counts()

# %%
#df['Ethnicity'].value_counts()

# %%
df['Education Level'].value_counts()
# Out:
# Bachelors      319
# Masters        189
# High School     36
# Associates      15
# PhD              5
# Name: Education Level, dtype: int64

# %%
df['Male/Female'].value_counts()
# Out:
# Male      456
# Female    160
# Name: Male/Female, dtype: int64

# %%
df.shape
# Out:
# (616, 20)

# %% [markdown]
# ## Standardize the Ethnicity column because i'm gonna need it

# %%
# Remove whitespace from the values in the Ethnicity column
df["Ethnicity_Cleaned"] = df["Ethnicity"].str.strip()

df_clean = df.drop(df[np.isin(df["Ethnicity"],['Native Hawaiian or other Pacific Islander',
                                          'Other (Please Specify):Bi-racial people should be able to check 2 options in 2022.',
                                               'Other (Please Specify):Bla',
                                               'Other (Please Specify):Half Asian half African',
                                               'Other (Please Specify):N/A',
                                               'Other (Please Specify)',
                                               'Other (Please Specify):Prefer not to ans',
                                               'Other (Please Specify):Race isn\'t a thing',
                                               'Other (Please Specify):Human',
                                               'Other (Please Specify):7',
                                               'Other (Please Specify):Bla',
                                               'Other (Please Specify):Melayu',
                                               'Other (Please Specify):Half black and half white',
                                               'Other (Please Specify):Mixed ( Caucasian / African-American )',
                                               'Other (Please Specify):Brown',
                                               'Other (Please Specify):Malay'])].index, inplace=False)

df["Ethnicity_Cleaned"] = df_clean["Ethnicity_Cleaned"]


#df["Ethnicity_Cleaned"] = df["Ethnicity_Cleaned"].str.upper()

df["Ethnicity_Cleaned"] = df["Ethnicity_Cleaned"].replace({
    "White or Caucasian": "WHITE",
   "Other (Please Specify):Greek":"WHITE",
    "Other (Please Specify):Russian":"WHITE",
    "Asian or Asian American": "ASIAN",
    "Other (Please Specify):Indian":"ASIAN",
    "American Indian or Alaska Native":"ASIAN",
    "Other (Please Specify):Dravidian":"ASIAN",
    "Other (Please Specify):Kurdish":"ASIAN",
    "Other (Please Specify):Asian":"ASIAN",
    "Other (Please Specify):Bangladeshi":"ASIAN",
    "Other (Please Specify):South Indian":"ASIAN",
    "Other (Please Specify):South Asian":"ASIAN",
    "Other (Please Specify):Pakistani":"ASIAN",
    "Black or African American": "BLACK",
    "Other (Please Specify):African":"BLACK",
    "Other (Please Specify):African":"BLACK",
    "Other (Please Specify):Sudanese African":"BLACK",
    "Other (Please Specify):Nigeria":"BLACK",
    "Other (Please Specify):Kenyan African":"BLACK",
    "Other (Please Specify):Black African, Zimbabwean Citizen":"BLACK",
    "Hispanic or Latino": "HISPANIC",
    "Other (Please Specify):Latino with Italian roots": "HISPANIC",
    "Other (Please Specify):Arab":"ARAB",
    "Other (Please Specify):Moroccan":"ARAB",
    "Other (Please Specify):Arab":"ARAB",
    "Other (Please Specify):arab":"ARAB",
    "Other (Please Specify):Arab":"ARAB",
    "Other (Please Specify):Arabian (from Maghreb)":"ARAB",
    "Other (Please Specify):Egyp":"ARAB",
    "Other (Please Specify):Middleeas":"ARAB",
  }, inplace=False)

df.head(100)
# Out:
#                     Unique ID  \
# 0    62a33b3db4da29969c62df3d
# 1    62a33ba1bae91e4b8b82e35c
# 2    62a33c2cbc6861bf3176bec1
# 3    62a33c8624a26260273822f9
# 4    62a33c91f3072dd892621e03
# 5    62a33cb6cf25554317300177
# 6    62a33cb72e54c9003e531c65
# 7    62a33cd30f8c8599d5af0f8f
# 8    62a33cd3cf255543173001d9
# 9    62a33cd8bc6861bf3176c05f
# 10   62a33ce918134ddc75ce8c30
# 11   62a33cf30a77c1a77f65baa2
# 12   62a33d15f408bae018ed370d
# 13   62a33d1ebae91e4b8b82e707
# 14   62a33d4624a26260273824c4
# 15   62a33d5c0f8c8599d5af107c
# 16   62a33d850f8c8599d5af10cb
# 17   62a33d9bf8f7561645852496
# 18   62a33dbdd8c00e9f5419cd65
# 19   62a33de124a26260273826b2
# 20   62a33dedd8c00e9f5419ce2b
# 21   62a33dfbd8c00e9f5419ceda
# 22   62a33e38f3072dd8926221d3
# 23   62a33e54d8c00e9f5419cfe9
# 24   62a33e62575fa3a5ae88aabf
# 25   62a33e63cec54911e9ca4f99
# 26   62a33e72bae91e4b8b82ea1a
# 27   62a33e890f8c8599d5af13b9
# 28   62a33e8bf8d5efcc22f7c79a
# 29   62a33e90cec54911e9ca5031
# ...

# %%
df['Ethnicity_Cleaned'].value_counts()
# Out:
# WHITE                                                                                 241
# ASIAN                                                                                 181
# BLACK                                                                                 111
# HISPANIC                                                                               74
# ARAB                                                                                    7
# Other (Please Specify):Half Asian half African                                          1
# Other (Please Specify):Bi-racial people should be able to check 2 options in 2022.      1
# Name: Ethnicity_Cleaned, dtype: int64

# %% [markdown]
# ## For the Salary I want to split the column, convert it to integer and get average salary from that
# ## So Here i'm gonna make an average column for the Salary

# %%
#splitting the salary column by '-' and remove the 'k' & '+'

#split salary column on '-' and remove the 'k'
salary = df['Yearly Salary(in USD)'].str.replace('k', '').str.split('-', expand = True).fillna(np.NaN)

#removing the '+'
salary[0] = salary[0].str.replace('+', '')

#fill the null rows with '225' for rows with '225+' initially so I can get the average
salary[1] = salary[1].fillna(salary[0])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_17392\3658037592.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   salary[0] = salary[0].str.replace('+', '')

# %%
#convert the salaries from object to int so I can erform mathematical operations

cols = [0, 1]

for col in cols:
    salary[col] = salary[col].astype(int)
    

#get the average of the salaries
salary['avg'] = (salary[0] + salary[1]) / 2

#view the new salary subset
salary.head()
# Out:
#      0    1    avg
# 0  106  125  115.5
# 1   41   65   53.0
# 2    0   40   20.0
# 3  150  225  187.5
# 4   41   65   53.0

# %%
#assign the avg salary to its own column in the main dataset

df['Average Salary'] = salary['avg']

#view dataset
df.head()
# Out:
#                   Unique ID                                     Job Title  \
# 0  62a33b3db4da29969c62df3d                                  Data Analyst
# 1  62a33ba1bae91e4b8b82e35c                                  Data Analyst
# 2  62a33c2cbc6861bf3176bec1                                 Data Engineer
# 3  62a33c8624a26260273822f9  Other (Please Specify):Analytics Consultant
# 4  62a33c91f3072dd892621e03                                  Data Analyst
#
#   Career Switch Yearly Salary(in USD)                        Work Industry  \
# 0           Yes             106k-125k                           Healthcare
# 1            No               41k-65k                              Finance
# 2            No                 0-40k  Other (Please Specify):Clean Energy
# 3           Yes             150k-225k                              Finance
# 4           Yes               41k-65k                           Healthcare
#
#   Favorite Programming Language  Happiness(Salary)  \
# ...

# %%
#df['Country'].value_counts()

# %% [markdown]
# ## Standardize the Country Column

# %%
df["Countries_Cleaned"] = df["Country"].str.strip()

df["Country_Cleaned"] = df["Country"].str.split(":", 1).str[-1]

df.head(50)
# Out:
#                    Unique ID  \
# 0   62a33b3db4da29969c62df3d
# 1   62a33ba1bae91e4b8b82e35c
# 2   62a33c2cbc6861bf3176bec1
# 3   62a33c8624a26260273822f9
# 4   62a33c91f3072dd892621e03
# 5   62a33cb6cf25554317300177
# 6   62a33cb72e54c9003e531c65
# 7   62a33cd30f8c8599d5af0f8f
# 8   62a33cd3cf255543173001d9
# 9   62a33cd8bc6861bf3176c05f
# 10  62a33ce918134ddc75ce8c30
# 11  62a33cf30a77c1a77f65baa2
# 12  62a33d15f408bae018ed370d
# 13  62a33d1ebae91e4b8b82e707
# 14  62a33d4624a26260273824c4
# 15  62a33d5c0f8c8599d5af107c
# 16  62a33d850f8c8599d5af10cb
# 17  62a33d9bf8f7561645852496
# 18  62a33dbdd8c00e9f5419cd65
# 19  62a33de124a26260273826b2
# 20  62a33dedd8c00e9f5419ce2b
# 21  62a33dfbd8c00e9f5419ceda
# 22  62a33e38f3072dd8926221d3
# 23  62a33e54d8c00e9f5419cfe9
# 24  62a33e62575fa3a5ae88aabf
# 25  62a33e63cec54911e9ca4f99
# 26  62a33e72bae91e4b8b82ea1a
# 27  62a33e890f8c8599d5af13b9
# 28  62a33e8bf8d5efcc22f7c79a
# 29  62a33e90cec54911e9ca5031
# 30  62a33e9df8f756164585277b
# ...

# %%
df['Country_Cleaned'].value_counts()
# Out:
# United States                    255
# India                             72
# United Kingdom                    39
# Canada                            31
# Nigeria                           18
# Germany                           14
# Nigeria                           10
# Spain                              9
# Australia                          7
# Poland                             6
# Kenya                              6
# Costa Rica                         6
# Mexico                             6
# Egypt                              6
# Argentina                          5
# Portugal                           5
# Netherlands                        5
# Colombia                           4
# Greece                             4
# Singapore                          3
# France                             3
# Romania                            3
# Other (Please Specify)             3
# South Africa                       2
# Indonesia                          2
# ...

# %% [markdown]
# ## Standardize the Job_Title Column

# %%
df['Job_Title_Cleaned'] = df['Job Title'].str.split(' \(Please', 1).str.get(0)
df.head(50)
# Out:
#                    Unique ID  \
# 0   62a33b3db4da29969c62df3d
# 1   62a33ba1bae91e4b8b82e35c
# 2   62a33c2cbc6861bf3176bec1
# 3   62a33c8624a26260273822f9
# 4   62a33c91f3072dd892621e03
# 5   62a33cb6cf25554317300177
# 6   62a33cb72e54c9003e531c65
# 7   62a33cd30f8c8599d5af0f8f
# 8   62a33cd3cf255543173001d9
# 9   62a33cd8bc6861bf3176c05f
# 10  62a33ce918134ddc75ce8c30
# 11  62a33cf30a77c1a77f65baa2
# 12  62a33d15f408bae018ed370d
# 13  62a33d1ebae91e4b8b82e707
# 14  62a33d4624a26260273824c4
# 15  62a33d5c0f8c8599d5af107c
# 16  62a33d850f8c8599d5af10cb
# 17  62a33d9bf8f7561645852496
# 18  62a33dbdd8c00e9f5419cd65
# 19  62a33de124a26260273826b2
# 20  62a33dedd8c00e9f5419ce2b
# 21  62a33dfbd8c00e9f5419ceda
# 22  62a33e38f3072dd8926221d3
# 23  62a33e54d8c00e9f5419cfe9
# 24  62a33e62575fa3a5ae88aabf
# 25  62a33e63cec54911e9ca4f99
# 26  62a33e72bae91e4b8b82ea1a
# 27  62a33e890f8c8599d5af13b9
# 28  62a33e8bf8d5efcc22f7c79a
# 29  62a33e90cec54911e9ca5031
# 30  62a33e9df8f756164585277b
# ...

# %%
df['Job_Title_Cleaned'].value_counts()
# Out:
# Data Analyst            371
# Student/Looking/None     88
# Other                    86
# Data Engineer            38
# Data Scientist           25
# Database Developer        5
# Data Architect            3
# Name: Job_Title_Cleaned, dtype: int64

# %% [markdown]
# ## Programming Language Standarization

# %%
df['Favorite_Programming_Language_Cleaned'] = df['Favorite Programming Language'].str.split(' \(Please', 1).str.get(0)
df['Favorite_Programming_Language_Cleaned'] = df['Favorite Programming Language'].str.split(':', 1).str.get(0)
df.head(20)
# Out:
#                    Unique ID                                     Job Title  \
# 0   62a33b3db4da29969c62df3d                                  Data Analyst
# 1   62a33ba1bae91e4b8b82e35c                                  Data Analyst
# 2   62a33c2cbc6861bf3176bec1                                 Data Engineer
# 3   62a33c8624a26260273822f9  Other (Please Specify):Analytics Consultant
# 4   62a33c91f3072dd892621e03                                  Data Analyst
# 5   62a33cb6cf25554317300177                                  Data Analyst
# 6   62a33cb72e54c9003e531c65                                Data Scientist
# 7   62a33cd30f8c8599d5af0f8f                                 Data Engineer
# 8   62a33cd3cf255543173001d9                                  Data Analyst
# 9   62a33cd8bc6861bf3176c05f                                  Data Analyst
# 10  62a33ce918134ddc75ce8c30                                  Data Analyst
# ...

# %%
df['Favorite_Programming_Language_Cleaned'].value_counts()
# Out:
# Python        410
# R             100
# Other          92
# C/C++           7
# JavaScript      6
# Java            1
# Name: Favorite_Programming_Language_Cleaned, dtype: int64

# %%
#df = df.drop("Countries_Cleaned", axis=1)
#df.head()

# %%
df.to_excel('D:\End-To-End_Project_Survey\Cleaned_Survey_Project2.xlsx', sheet_name = 'Cleaned_Project', index = False)
